# %%
# %pylab inline
import pandas as pd
import os
from tqdm import tqdm
import fnmatch
import errno    
import glob
from textwrap import dedent
from riboraptor.helpers import mkdir_p
from riboraptor.sradb import SRAdb
from riboraptor.utils import copy_sra_data, create_config_file

def mkdir_p(path):
    """Python version mkdir -p

    Parameters
    ----------

    path : str
    """
    if path:
        try:
            os.makedirs(path)
        except OSError as exc:  # Python >2.5
            if exc.errno == errno.EEXIST and os.path.isdir(path):
                pass
            else:
                raise


def symlink_force(source, destination):
    """Create forcelink forcefully

    Parameters
    ----------
    source: string
            Location to source file
    destination: string
                 Location to target

    """
    try:
        os.symlink(source, destination)
    except OSError as exc:
        if exc.errno == errno.EEXIST:
            os.remove(destination)
            os.symlink(source, destination)
        else:
            raise exc
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['dedent']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
re_ribo_root_dir = '/staging/as/skchoudh/SRA_datasets/'
samples_to_process_dir = '/staging/as/skchoudh/re-ribo-datasets/'
re_ribo_config_dir = '/home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs'
re_ribo_analysis_dir = '/staging/as/skchoudh/re-ribo-analysis/'
riboraptor_annotation_dir = '/home/cmb-panasas2/skchoudh/github_projects/riboraptor/riboraptor/annotation/'
def mkdir_p(path):
    """Python version mkdir -p

    Parameters
    ----------

    path : str
    """
    if path:
        try:
            os.makedirs(path)
        except OSError as exc:  # Python >2.5
            if exc.errno == errno.EEXIST and os.path.isdir(path):
                pass
            else:
                raise


def symlink_force(source, destination):
    """Create forcelink forcefully

    Parameters
    ----------
    source: string
            Location to source file
    destination: string
                 Location to target

    """
    try:
        os.symlink(source, destination)
    except OSError as exc:
        if exc.errno == errno.EEXIST:
            os.remove(destination)
            os.symlink(source, destination)
        else:
            raise exc
genome_annotation_map = {
    'hg38': 'v25',
    'mm10': 'vM11',
    'mg1655': '',
    'sacCerR64': 'v91',
    'MG1655': 'ASM584v2.38',
    'BDGP6': 'v91',
    'GRCz10': 'v91',
    'panTro3': 'v94',
    'Mmul8': 'v94'
}


genome_fasta_map = {
    'hg38':
    '/home/cmb-panasas2/skchoudh/genomes/hg38/fasta/hg38.fa',
    'mm10':
    '/home/cmb-panasas2/skchoudh/genomes/mm10/fasta/mm10.fa',
    'sacCerR64':
    '/home/cmb-panasas2/skchoudh/genomes/sacCerR64/fasta/Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa',
    'MG1655':
    '/home/cmb-panasas2/skchoudh/genomes/escherichia_coli_str_k_12_substr_mg1655/fasta/Escherichia_coli_str_k_12_substr_mg1655.ASM584v2.dna.toplevel.fa',
    'BDGP6':
    '/home/cmb-panasas2/skchoudh/genomes/drosophila_melanogaster_BDGP6/fasta/Drosophila_melanogaster.BDGP6.dna.toplevel.fa',
    'GRCz10':
    '/home/cmb-panasas2/skchoudh/genomes/GRCz10/fasta/Danio_rerio.GRCz10.dna.toplevel.fa',
    'panTro3':
    '/home/cmb-panasas2/skchoudh/genomes/panTro3/fasta/Pan_troglodytes.Pan_tro_3.0.dna.toplevel.fa',
    'Mmul8':
    '/home/cmb-panasas2/skchoudh/genomes/Mmul8/fasta/Macaca_mulatta.Mmul_8.0.1.dna.toplevel.fa'
}

chrom_sizes_map = {
    'hg38':
    '/home/cmb-panasas2/skchoudh/genomes/hg38/fasta/hg38.chrom.sizes',
    'mm10':
    '/home/cmb-panasas2/skchoudh/genomes/mm10/fasta/mm10.chrom.sizes',
    'sacCerR64':
    '/home/cmb-panasas2/skchoudh/genomes/sacCerR64/fasta/Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.sizes',
    'MG1655':
    '/home/cmb-panasas2/skchoudh/genomes/escherichia_coli_str_k_12_substr_mg1655/fasta/Escherichia_coli_str_k_12_substr_mg1655.ASM584v2.dna.toplevel.sizes',
    'BDGP6':
    '/home/cmb-panasas2/skchoudh/genomes/drosophila_melanogaster_BDGP6/fasta/Drosophila_melanogaster.BDGP6.dna.toplevel.sizes',
    'GRCz10':
    '/home/cmb-panasas2/skchoudh/genomes/GRCz10/fasta/Danio_rerio.GRCz10.dna.toplevel.sizes',
    'panTro3':
    '/home/cmb-panasas2/skchoudh/genomes/panTro3/fasta/Pan_troglodytes.Pan_tro_3.0.dna.toplevel.sizes',
    'Mmul8':
    '/home/cmb-panasas2/skchoudh/genomes/Mmul8/fasta/Macaca_mulatta.Mmul_8.0.1.dna.toplevel.sizes'
}

star_index_map = {
    'hg38':
    '/home/cmb-panasas2/skchoudh/genomes/hg38/star_annotated',
    'mm10':
    '/home/cmb-panasas2/skchoudh/genomes/mm10/star_annotated',
    'sacCerR64':
    '/home/cmb-panasas2/skchoudh/genomes/sacCerR64/star_annotated',
    'MG1655':
    '/home/cmb-panasas2/skchoudh/genomes/escherichia_coli_str_k_12_substr_mg1655/star_annotated',
    'BDGP6':
    '/home/cmb-panasas2/skchoudh/genomes/drosophila_melanogaster_BDGP6/star_annotated',
    'GRCz10':
    '/home/cmb-panasas2/skchoudh/genomes/GRCz10/star_annotated',
    'panTro3':
    '/home/cmb-panasas2/skchoudh/genomes/panTro3/star_annotated',
    'Mmul8':
    '/home/cmb-panasas2/skchoudh/genomes/Mmul8/star_annotated'
}

gtf_map = {
    'hg38':
    '/home/cmb-panasas2/skchoudh/genomes/hg38/annotation/gencode.v25.annotation.gtf',
    'mm10':
    '/home/cmb-panasas2/skchoudh/genomes/mm10/annotation/gencode.vM11.annotation.gtf',
    'sacCerR64':
    '/home/cmb-panasas2/skchoudh/genomes/sacCerR64/annotation/Saccharomyces_cerevisiae.R64-1-1.91.gtf',
    'MG1655':
    '/home/cmb-panasas2/skchoudh/genomes/escherichia_coli_str_k_12_substr_mg1655/annotation/Escherichia_coli_str_k_12_substr_mg1655.ASM584v2.38.gtf',
    'BDGP6':
    '/home/cmb-panasas2/skchoudh/genomes/drosophila_melanogaster_BDGP6/annotation/Drosophila_melanogaster.BDGP6.91.gtf',
    'GRCz10':
    '/home/cmb-panasas2/skchoudh/genomes/GRCz10/annotation/Danio_rerio.GRCz10.91.gtf',
    'Mmul8':
    '/home/cmb-panasas2/skchoudh/genomes/Mmul8/annotation/Macaca_mulatta.Mmul_8.0.1.94.gtf',
    'panTro3':
    '/home/cmb-panasas2/skchoudh/genomes/panTro3/annotation/Pan_troglodytes.Pan_tro_3.0.94.gtf'
}


def filter_single_end_samples(df):
    """Filter single end samples from a dataframe

    Parameters
    ----------
    df: DataFrame
        Dataframe as obtained from SRAb.sra_convert()

    Returns
    -------
    df: DataFrame
        DataFrame with only single end samples
    """
    df = df[~df['library_strategy'].str.contains('PAIRED')]
    return df


def copy_sra_data(df,
                  sra_source_dir='/staging/as/skchoudh/SRA_datasets/',
                  sra_dest_dir='/staging/as/skchoudh/re-ribo-datasets/'):
    """Copy SRA data to a new location retaining only single ended samples."""
    df = filter_single_end_samples(df)
    assert len(df.study_accession.unique()) == 1, 'Multiple SRPs found'
    srp = df.study_accession.unique()[0]
    df_grouped = df.groupby(['taxon_id'])
    srp_source_dir = os.path.join(sra_source_dir, srp)

    for taxon_id, df_group in df_grouped:
        species = taxon_id_map[taxon_id]
        species_dest_dir = os.path.join(sra_dest_dir, species)
        srp_dest_dir = os.path.join(species_dest_dir, srp)
        mkdir_p(os.path.join(species_dest_dir, srp))
        source_loc = srp_source_dir + os.path.sep + df_group[
            'experiment_accession'].str.cat(
                df_group['run_accession'] + '.sra', sep=os.path.sep)
        dest_loc = srp_dest_dir + os.path.sep + df_group[
            'experiment_accession'].str.cat(
                df_group['run_accession'] + '.sra', sep=os.path.sep)
        with tqdm(total=len(source_loc)) as pbar:
            for source, dest in zip(source_loc, dest_loc):
                mkdir_p(os.path.dirname(dest))
                if os.path.isfile(source):
                    symlink_force(source, dest)
                pbar.update()

# %%
db = SRAdb('/staging/as/skchoudh/SRAmetadb.sqlite')

# %%
srp = 'SRP012040'
df = db.sra_convert(srp)
df
# Out:
#     study_accession experiment_accession  \
# 0         SRP012040            SRX135150
# 1         SRP012040            SRX135150
# 2         SRP012040            SRX135150
# 3         SRP012040            SRX135150
# 4         SRP012040            SRX135150
# 5         SRP012040            SRX135150
# 6         SRP012040            SRX135150
# 7         SRP012040            SRX135150
# 8         SRP012040            SRX135150
# 9         SRP012040            SRX135150
# 10        SRP012040            SRX135151
# 11        SRP012040            SRX135151
# 12        SRP012040            SRX135151
# 13        SRP012040            SRX135151
# 14        SRP012040            SRX135151
# 15        SRP012040            SRX135151
# 16        SRP012040            SRX135152
# 17        SRP012040            SRX135152
# 18        SRP012040            SRX135152
# 19        SRP012040            SRX135152
# 20        SRP012040            SRX135152
# 21        SRP012040            SRX135152
# 22        SRP012040            SRX135153
# 23        SRP012040            SRX135153
# 24        SRP012040            SRX135153
# 25        SRP012040            SRX135153
# 26        SRP012040            SRX135153
# 27        SRP012040            SRX135153
# 28        SRP012040            SRX135153
# 29        SRP012040            SRX135153
# ..              ...                  ...
# 95        SRP012040            SRX135166
# 96        SRP012040            SRX135166
# 97        SRP012040            SRX135166
# 98        SRP012040            SRX135166
# 99        SRP012040            SRX186041
# 100       SRP012040            SRX186041
# 101       SRP012040            SRX186042
# 102       SRP012040            SRX186042
# 103       SRP012040            SRX186043
# 104       SRP012040            SRX186043
# 105       SRP012040            SRX186044
# 106       SRP012040            SRX186044
# 107       SRP012040            SRX186045
# 108       SRP012040            SRX186045
# 109       SRP012040            SRX186046
# 110       SRP012040            SRX186046
# 111       SRP012040            SRX186047
# 112       SRP012040            SRX186047
# 113       SRP012040            SRX186048
# 114       SRP012040            SRX186048
# 115       SRP012040            SRX186049
# 116       SRP012040            SRX186049
# 117       SRP012040            SRX186050
# 118       SRP012040            SRX186050
# 119       SRP012040            SRX186051
# 120       SRP012040            SRX186051
# 121       SRP012040            SRX186052
# 122       SRP012040            SRX186052
# 123       SRP012040            SRX186053
# 124       SRP012040            SRX186053
#
#                                    experiment_title run_accession  taxon_id  \
# 0           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453077     10090
# 1           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453078     10090
# 2           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453079     10090
# 3           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453080     10090
# 4           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453081     10090
# 5           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453082     10090
# 6           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453083     10090
# 7           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453084     10090
# 8           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453085     10090
# 9           GSM900183: CSHL_RnaSeq_Ovary_adult-8wks     SRR453086     10090
# 10   GSM900184: CSHL_RnaSeq_MammaryGland_adult-8wks     SRR453087     10090
# 11   GSM900184: CSHL_RnaSeq_MammaryGland_adult-8wks     SRR453088     10090
# 12   GSM900184: CSHL_RnaSeq_MammaryGland_adult-8wks     SRR453089     10090
# 13   GSM900184: CSHL_RnaSeq_MammaryGland_adult-8wks     SRR453090     10090
# 14   GSM900184: CSHL_RnaSeq_MammaryGland_adult-8wks     SRR453091     10090
# 15   GSM900184: CSHL_RnaSeq_MammaryGland_adult-8wks     SRR453092     10090
# 16        GSM900185: CSHL_RnaSeq_Stomach_adult-8wks     SRR453093     10090
# 17        GSM900185: CSHL_RnaSeq_Stomach_adult-8wks     SRR453094     10090
# 18        GSM900185: CSHL_RnaSeq_Stomach_adult-8wks     SRR453095     10090
# 19        GSM900185: CSHL_RnaSeq_Stomach_adult-8wks     SRR453096     10090
# 20        GSM900185: CSHL_RnaSeq_Stomach_adult-8wks     SRR453097     10090
# 21        GSM900185: CSHL_RnaSeq_Stomach_adult-8wks     SRR453098     10090
# 22    GSM900186: CSHL_RnaSeq_SmIntestine_adult-8wks     SRR453099     10090
# 23    GSM900186: CSHL_RnaSeq_SmIntestine_adult-8wks     SRR453100     10090
# 24    GSM900186: CSHL_RnaSeq_SmIntestine_adult-8wks     SRR453101     10090
# 25    GSM900186: CSHL_RnaSeq_SmIntestine_adult-8wks     SRR453102     10090
# 26    GSM900186: CSHL_RnaSeq_SmIntestine_adult-8wks     SRR453103     10090
# 27    GSM900186: CSHL_RnaSeq_SmIntestine_adult-8wks     SRR453104     10090
# 28    GSM900186: CSHL_RnaSeq_SmIntestine_adult-8wks     SRR453105     10090
# 29    GSM900186: CSHL_RnaSeq_SmIntestine_adult-8wks     SRR453106     10090
# ..                                              ...           ...       ...
# 95          GSM900199: CSHL_RnaSeq_Heart_adult-8wks     SRR453172     10090
# 96          GSM900199: CSHL_RnaSeq_Heart_adult-8wks     SRR453173     10090
# 97          GSM900199: CSHL_RnaSeq_Heart_adult-8wks     SRR453174     10090
# 98          GSM900199: CSHL_RnaSeq_Heart_adult-8wks     SRR453175     10090
# 99   GSM1000562: CSHL_RnaSeq_FrontalLobe_adult-8wks     SRR567478     10090
# 100  GSM1000562: CSHL_RnaSeq_FrontalLobe_adult-8wks     SRR567479     10090
# 101       GSM1000563: CSHL_RnaSeq_Cortex_adult-8wks     SRR567480     10090
# 102       GSM1000563: CSHL_RnaSeq_Cortex_adult-8wks     SRR567481     10090
# 103      GSM1000564: CSHL_RnaSeq_Bladder_adult-8wks     SRR567482     10090
# 104      GSM1000564: CSHL_RnaSeq_Bladder_adult-8wks     SRR567483     10090
# 105     GSM1000565: CSHL_RnaSeq_Placenta_adult-8wks     SRR567484     10090
# 106     GSM1000565: CSHL_RnaSeq_Placenta_adult-8wks     SRR567485     10090
# 107               GSM1000566: CSHL_RnaSeq_Liver_E18     SRR567486     10090
# 108               GSM1000566: CSHL_RnaSeq_Liver_E18     SRR567487     10090
# 109   GSM1000567: CSHL_RnaSeq_Cerebellum_adult-8wks     SRR567488     10090
# 110   GSM1000567: CSHL_RnaSeq_Cerebellum_adult-8wks     SRR567489     10090
# 111              GSM1000568: CSHL_RnaSeq_Limb_E14.5     SRR567490     10090
# 112              GSM1000568: CSHL_RnaSeq_Limb_E14.5     SRR567491     10090
# 113                 GSM1000569: CSHL_RnaSeq_CNS_E14     SRR567492     10090
# 114                 GSM1000569: CSHL_RnaSeq_CNS_E14     SRR567493     10090
# 115                 GSM1000570: CSHL_RnaSeq_CNS_E18     SRR567494     10090
# 116                 GSM1000570: CSHL_RnaSeq_CNS_E18     SRR567495     10090
# 123         None            202.0
# 124         None            202.0
#
# [125 rows x 14 columns]

# %%
srp = 'SRP016501'
df = db.sra_convert(srp)
#copy_sra_data(df)

# %%
srp = 'SRP007412'
df = db.sra_convert(srp)
df.head()
# Out:
#   study_accession experiment_accession       experiment_title run_accession  \
# 0       SRP007412            SRX081869  GSM752557: gga br F 1     SRR306710
# 1       SRP007412            SRX081870  GSM752558: gga br M 1     SRR306711
# 2       SRP007412            SRX081871  GSM752559: gga cb F 1     SRR306712
# 3       SRP007412            SRX081872  GSM752560: gga cb M 1     SRR306713
# 4       SRP007412            SRX081873  GSM752561: gga ht F 1     SRR306714
#
#    taxon_id library_selection library_layout library_strategy  library_source  \
# 0      9031              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
# 1      9031              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
# 2      9031              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
# 3      9031              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
# 4      9031              cDNA      SINGLE -           RNA-Seq  TRANSCRIPTOMIC
#
#             library_name       bases     spots adapter_spec  avg_read_length
# 0  GSM752557: gga br F 1  1480245008  19476908         None             76.0
# 1  GSM752558: gga br M 1  1334334888  17557038         None             76.0
# 2  GSM752559: gga cb F 1  1795697524  23627599         None             76.0
# 3  GSM752560: gga cb M 1  1670739920  21983420         None             76.0
# 4  GSM752561: gga ht F 1  1748333260  23004385         None             76.0

# %%
#df[df.taxon_id==9031]
df.taxon_id.unique()
# Out:
# array([ 9031,  9258,  9544,  9593,  9597,  9598,  9600,  9606, 10090,
#        13616])

# %%
taxon_id_map = {
    10090: 'mus_musculus',
    9606: 'homo_sapiens',
    4932: 'sacCerR64',
    511145: 'MG1655',
    7227: 'drosophila_melanogaster',
    7955: 'danio_rerio',
    9598: 'pan_troglodytes',
    9544: 'macaca_mulatta',
    9031: 'gallus_gallus',
    9913: 'bos_taurus',
    10116: 'rattus_norvegicus',
    9258: 'ornithorhynchus_anatinus',
    9593: 'gorilla_gorilla',
    9597: 'pan_paniscus',
    9600: 'pongo_abelii', #'pongo_pygmaeus',
    13616: 'monodelphis_domestica'
    
}

genomes_dir = '/home/cmb-panasas2/skchoudh/genomes'
re_ribo_analysis_dir = '/staging/as/skchoudh/rna-seq-output'

# %%
taxon_id_map = {
    10090: 'mus_musculus',
    9606: 'homo_sapiens',
    4932: 'sacCerR64',
    511145: 'MG1655',
    7227: 'drosophila_melanogaster',
    7955: 'danio_rerio',
    9598: 'pan_troglodytes',
    9544: 'macaca_mulatta',
    9031: 'gallus_gallus',
    9913: 'bos_taurus',
    10116: 'rattus_norvegicus',
    9258: 'ornithorhynchus_anatinus',
    9593: 'gorilla_gorilla',
    9597: 'pan_paniscus',
    9600: 'pongo_abelii', #'pongo_pygmaeus',
    13616: 'monodelphis_domestica'
    
}

genomes_dir = '/home/cmb-panasas2/skchoudh/genomes'

cdna_map = {}
for value in taxon_id_map.values():
    genome_dir = os.path.join(genomes_dir, value)
    if os.path.exists(os.path.join(genome_dir, 'cdna')):
        cdna_map[value] = glob.glob('{}/*'.format(os.path.join(genome_dir, 'cdna')))[0]
def create_config_file(df):
    df_grouped = df.groupby(['taxon_id'])

    for taxon_id, df_group in df_grouped:
        assert len(
            df_group['study_accession'].unique()) == 1, 'Multiple SRPs found'
        species = taxon_id_map[taxon_id]
        srp = df_group['study_accession'].unique()[0]
        with open(
                os.path.join(re_ribo_config_dir, '{}_{}.py'.format(
                    species, srp)), 'w') as fh:

            config = write_config(species, srp)
            fh.write(config)
            print('Wrote {}'.format(
                os.path.join(re_ribo_config_dir, '{}_{}.py'.format(
                    species, srp))))

# %%
def copy_sra_data(df,
                  sra_source_dir='/staging/as/skchoudh/SRA_datasets/',
                  sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/'):
    """Copy SRA data to a new location retaining only single ended samples."""
    assert len(df.study_accession.unique()) == 1, 'Multiple SRPs found'
    srp = df.study_accession.unique()[0]
    df_grouped = df.groupby(['taxon_id'])
    srp_source_dir = os.path.join(sra_source_dir, srp)

    for taxon_id, df_group in df_grouped:
        species = taxon_id_map[taxon_id]
        species_dest_dir = os.path.join(sra_dest_dir, species)
        srp_dest_dir = os.path.join(species_dest_dir, srp)
        mkdir_p(os.path.join(species_dest_dir, srp))
        source_loc = srp_source_dir + os.path.sep + df_group[
            'experiment_accession'].str.cat(
                df_group['run_accession'] + '.sra', sep=os.path.sep)
        dest_loc = srp_dest_dir + os.path.sep + df_group[
            'experiment_accession'].str.cat(
                df_group['run_accession'] + '.sra', sep=os.path.sep)
        with tqdm(total=len(source_loc)) as pbar:
            for source, dest in zip(source_loc, dest_loc):
                mkdir_p(os.path.dirname(dest))
                if os.path.isfile(source):
                    symlink_force(source, dest)
                pbar.update()

# %%
sorted(db.desc_table('sra_ft')['name'].tolist())
# Out:
# ['SRR_bamFile',
#  'SRX_bamFile',
#  'SRX_fastqFTP',
#  'adapter_spec',
#  'anonymized_name',
#  'base_caller',
#  'bases',
#  'center_project_name',
#  'common_name',
#  'description',
#  'design_description',
#  'experiment_ID',
#  'experiment_accession',
#  'experiment_alias',
#  'experiment_attribute',
#  'experiment_entrez_link',
#  'experiment_name',
#  'experiment_title',
#  'experiment_url_link',
#  'individual_name',
#  'instrument_model',
#  'instrument_name',
#  'library_construction_protocol',
#  'library_layout',
#  'library_name',
#  'library_selection',
#  'library_source',
#  'library_strategy',
#  'multiplier',
#  'number_of_levels',
#  'platform',
#  'platform_parameters',
#  'primary_study',
#  'qtype',
#  'quality_scorer',
#  'read_spec',
#  'related_studies',
#  'run_ID',
#  'run_accession',
#  'run_alias',
#  'run_attribute',
#  'run_center',
#  'run_date',
#  'run_entrez_link',
#  'run_url_link',
#  'sample_ID',
#  'sample_accession',
#  'sample_alias',
#  'sample_attribute',
#  'sample_entrez_link',
#  'sample_name',
#  'sample_url_link',
#  'sequence_space',
#  'spots',
#  'sradb_updated',
#  'study_ID',
#  'study_abstract',
#  'study_accession',
#  'study_alias',
#  'study_attribute',
#  'study_description',
#  'study_entrez_link',
#  'study_name',
#  'study_title',
#  'study_type',
#  'study_url_link',
#  'submission_ID',
#  'submission_accession',
#  'submission_center',
#  'submission_comment',
#  'submission_date',
#  'submission_lab',
#  'taxon_id',
#  'updated_date']

# %%
srp = 'SRP016501'
df = db.sra_convert(srp)
copy_sra_data(df)
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 325.50it/s]
# 100%|██████████| 27/27 [00:00<00:00, 369.01it/s]
# 100%|██████████| 27/27 [00:00<00:00, 372.44it/s]
# 100%|██████████| 26/26 [00:00<00:00, 393.26it/s]
# 100%|██████████| 27/27 [00:00<00:00, 407.28it/s]

# %%
srp = 'SRP016501'
df = db.sra_convert(srp)
copy_sra_data(df)

# %%
srp = 'SRP016501'
prefix = '/home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/{}'.format(srp)
cols = ['study_accession',
 'experiment_accession',
 'experiment_title',
 'run_accession',
 'taxon_id',
 'library_selection',
 'library_layout',
 'library_strategy',
 'library_source',
 'library_name',
 'bases',
 'spots',
 'adapter_spec', 'description']

# %%
df = db.sra_convert(srp, out_type=cols)
df['tissue'] = df['experiment_title'].str.split(': ').str.get(1).str.split('; ').str.get(0)
df = df.sort_values(by=['tissue', 'experiment_accession'])
for taxon_id, group in df[['study_accession', 'experiment_accession', 'taxon_id', 'tissue']].drop_duplicates().groupby(['taxon_id']):
    species = taxon_id_map[taxon_id]
    filepath = '{}-{}.tsv'.format(prefix, species)
    #rint(group)
    group = group.sort_values(by=['tissue', 'experiment_accession'])
    abundances = pd.DataFrame()
    for index, row in group.iterrows():
        srp =  row['study_accession']
        tissue = ('_').join(row['tissue'].split('_')[1:])
        srx = row['experiment_accession']
        
        abundance = pd.read_table('/staging/as/skchoudh/rna-seq-output/{}/{}/counts/{}/abundance.tsv'.format(species, srp, srx)) [['target_id', 'tpm']].rename(columns={'tpm': tissue}).set_index('target_id')
        #    target_id       length  eff_length      est_counts      tpm

        abundances = abundances.join(abundance, how='outer')
    abundances = abundances.reset_index()
    abundances.to_csv(filepath, header=True,  index=False, sep='\t')
    print('Wrote: {}'.format(filepath))
# Out:
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP016501-gallus_gallus.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP016501-macaca_mulatta.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP016501-bos_taurus.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP016501-mus_musculus.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP016501-rattus_norvegicus.tsv

# %%
srp = 'SRP016501'

df = db.sra_convert(srp, out_type=cols)
df['tissue'] = df['experiment_title'].str.split(': ').str.get(1).str.split('; ').str.get(0)
df = df.sort_values(by=['tissue', 'experiment_accession'])
with open('../cross-species-data/SRP016501_sample_info.tsv', 'w') as fh:
    fh.write('sample\tspecies\ttissue\n')
    for taxon_id, group in df[['study_accession', 'experiment_accession', 'taxon_id', 'tissue']].drop_duplicates().groupby(['taxon_id']):
        species = taxon_id_map[taxon_id]
        filepath = '{}-{}.tsv'.format(prefix, species)
        #rint(group)
        group = group.sort_values(by=['tissue', 'experiment_accession'])
        abundances = pd.DataFrame()
        for index, row in group.iterrows():
            srp =  row['study_accession']
            tissue = ('_').join(row['tissue'].split('_')[1:])
            srx = row['experiment_accession']
            fh.write('{}\t{}\t{}\n'.format(srx, species, tissue))

# %%
create_config_file(df)
# Out:
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/gallus_gallus_SRP016501.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/macaca_mulatta_SRP016501.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/bos_taurus_SRP016501.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/mus_musculus_SRP016501.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/rattus_norvegicus_SRP016501.py

# %%
srp = 'SRP007412'
df = db.sra_convert(srp)
prefix = '/home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/{}'.format(srp)

#copy_sra_data(df)
df = db.sra_convert(srp, out_type=cols+['experiment_name'])
df['tissue'] = df['experiment_title'].str.split(': ').str.get(1).str[3:].str.lstrip(' ').str.replace(' ', '_')
df = df.sort_values(by=['tissue', 'experiment_accession'])

for taxon_id, group in df[['study_accession', 'experiment_accession', 'taxon_id', 'tissue']].drop_duplicates().groupby(['taxon_id']):
    species = taxon_id_map[taxon_id]
    filepath = '{}-{}.tsv'.format(prefix, species)
    #rint(group)
    group = group.sort_values(by=['tissue', 'experiment_accession'])
    abundances = pd.DataFrame()
    for index, row in group.iterrows():
        srp =  row['study_accession']
        tissue = row['tissue']
        srx = row['experiment_accession']
        
        abundance = pd.read_table('/staging/as/skchoudh/rna-seq-output/{}/{}/counts/{}/abundance.tsv'.format(species, srp, srx)) [['target_id', 'tpm']].rename(columns={'tpm': tissue}).set_index('target_id')
        #    target_id       length  eff_length      est_counts      tpm

        abundances = abundances.join(abundance, how='outer')
    abundances = abundances.reset_index()
    abundances.to_csv(filepath, header=True,  index=False, sep='\t')
    print('Wrote: {}'.format(filepath))
#create_config_file(df)
# Out:
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-gallus_gallus.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-ornithorhynchus_anatinus.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-macaca_mulatta.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-gorilla_gorilla.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-pan_paniscus.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-pan_troglodytes.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-pongo_abelii.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-homo_sapiens.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-mus_musculus.tsv
# Wrote: /home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/SRP007412-monodelphis_domestica.tsv

# %%
srp = 'SRP007412'
df = db.sra_convert(srp)
prefix = '/home/cmb-panasas2/skchoudh/github_projects/EE-546-project/cross-species-data/{}'.format(srp)

#copy_sra_data(df)
df = db.sra_convert(srp, out_type=cols+['experiment_name'])
df['tissue'] = df['experiment_title'].str.split(': ').str.get(1).str[3:].str.lstrip(' ').str.replace(' ', '_')
df = df.sort_values(by=['tissue', 'experiment_accession'])
with open('../cross-species-data/SRP007412_sample_info.tsv', 'w') as fh:
    fh.write('sample\tspecies\ttissue\n')
    for taxon_id, group in df[['study_accession', 'experiment_accession', 'taxon_id', 'tissue']].drop_duplicates().groupby(['taxon_id']):
        species = taxon_id_map[taxon_id]
        filepath = '{}-{}.tsv'.format(prefix, species)
        #rint(group)
        group = group.sort_values(by=['tissue', 'experiment_accession'])
        abundances = pd.DataFrame()
        for index, row in group.iterrows():
            srp =  row['study_accession']
            tissue = row['tissue']
            srx = row['experiment_accession']
            fh.write('{}\t{}\t{}\n'.format(srx, species, tissue))

# %%
df.head()

# %%
df[df.library_strategy.str.contains('PAIRED')]
# Out:
# Empty DataFrame
# Columns: [study_accession, experiment_accession, experiment_title, run_accession, taxon_id, library_selection, library_layout, library_strategy, library_source, library_name, bases, spots, adapter_spec, description, avg_read_length, tissue]
# Index: []

# %%
df_paired = df[df.avg_read_length>76]
df_unpaired = df[df.library_layout.str.contains('SINGLE')]

# %%
copy_sra_data(df)
# Out:
#     study_accession experiment_accession       experiment_title run_accession  \
# 0         SRP007412            SRX081869  GSM752557: gga br F 1     SRR306710
# 1         SRP007412            SRX081870  GSM752558: gga br M 1     SRR306711
# 2         SRP007412            SRX081871  GSM752559: gga cb F 1     SRR306712
# 3         SRP007412            SRX081872  GSM752560: gga cb M 1     SRR306713
# 4         SRP007412            SRX081873  GSM752561: gga ht F 1     SRR306714
# 5         SRP007412            SRX081874  GSM752562: gga ht M 1     SRR306715
# 6         SRP007412            SRX081875  GSM752563: gga kd F 1     SRR306716
# 7         SRP007412            SRX081876  GSM752564: gga kd M 1     SRR306717
# 8         SRP007412            SRX081877  GSM752565: gga lv F 1     SRR306718
# 9         SRP007412            SRX081878  GSM752566: gga lv M 1     SRR306719
# 10        SRP007412            SRX081878  GSM752566: gga lv M 1     SRR306720
# 11        SRP007412            SRX081879  GSM752567: gga ts M 1     SRR306721
# 12        SRP007412            SRX081879  GSM752567: gga ts M 1     SRR306722
# 13        SRP007412            SRX081880  GSM752568: gga ts M 2     SRR306723
# 14        SRP007412            SRX081881  GSM752569: oan br F 1     SRR306724
# 15        SRP007412            SRX081881  GSM752569: oan br F 1     SRR306725
# 16        SRP007412            SRX081882  GSM752570: oan br M 1     SRR306726
# 17        SRP007412            SRX081882  GSM752570: oan br M 1     SRR306727
# 18        SRP007412            SRX081883  GSM752571: oan cb F 1     SRR306728
# 19        SRP007412            SRX081884  GSM752572: oan cb M 1     SRR306729
# 20        SRP007412            SRX081885  GSM752573: oan ht F 1     SRR306730
# 21        SRP007412            SRX081886  GSM752575: oan ht M 1     SRR306731
# 22        SRP007412            SRX081887  GSM752576: oan kd F 1     SRR306732
# 23        SRP007412            SRX081888  GSM752578: oan kd M 1     SRR306733
# 24        SRP007412            SRX081888  GSM752578: oan kd M 1     SRR306734
# 25        SRP007412            SRX081889  GSM752580: oan lv F 1     SRR306735
# 26        SRP007412            SRX081889  GSM752580: oan lv F 1     SRR306736
# 27        SRP007412            SRX081890  GSM752581: oan lv M 1     SRR306737
# 28        SRP007412            SRX081890  GSM752581: oan lv M 1     SRR306738
# 29        SRP007412            SRX081891  GSM752583: oan ts M 1     SRR306739
# ..              ...                  ...                    ...           ...
# 119       SRP007412            SRX081907  GSM752616: mmu br M 2     SRR306762
# 120       SRP007412            SRX081908  GSM752617: mmu cb F 1     SRR306763
# 121       SRP007412            SRX081909  GSM752618: mmu cb M 1     SRR306764
# 122       SRP007412            SRX081910  GSM752619: mmu cb M 2     SRR306765
# 123       SRP007412            SRX081911  GSM752620: mmu ht F 1     SRR306766
# 124       SRP007412            SRX081912  GSM752621: mmu ht M 1     SRR306767
# 125       SRP007412            SRX081913  GSM752622: mmu ht M 2     SRR306768
# 126       SRP007412            SRX081914  GSM752623: mmu kd F 1     SRR306769
# 127       SRP007412            SRX081915  GSM752624: mmu kd M 1     SRR306770
# 128       SRP007412            SRX081916  GSM752625: mmu kd M 2     SRR306771
# 129       SRP007412            SRX081917  GSM752626: mmu lv F 1     SRR306772
# 130       SRP007412            SRX081918  GSM752627: mmu lv M 1     SRR306773
# 131       SRP007412            SRX081919  GSM752628: mmu lv M 2     SRR306774
# 132       SRP007412            SRX081920  GSM752629: mmu ts M 1     SRR306775
# 133       SRP007412            SRX081921  GSM752630: mmu ts M 2     SRR306776
# 134       SRP007412            SRX081893  GSM752588: mdo br F 1     SRR306742
# 135       SRP007412            SRX081893  GSM752588: mdo br F 1     SRR306743
# 136       SRP007412            SRX081894  GSM752590: mdo br M 1     SRR306744
# 137       SRP007412            SRX081895  GSM752592: mdo cb F 1     SRR306745
# 138       SRP007412            SRX081896  GSM752594: mdo cb M 1     SRR306746
# 0               76.0
# 1               76.0
# 2               76.0
# 3               76.0
# 4               76.0
# 5               76.0
# 6               76.0
# 7               76.0
# 8               76.0
# 9               76.0
# 10              76.0
# 11              76.0
# 12              76.0
# 13              76.0
# 14              76.0
# 15              76.0
# 16              76.0
# 17              76.0
# 18              76.0
# 19              76.0
# 20              76.0
# 21              76.0
# 22              76.0
# 23              76.0
# 24              76.0
# 25              76.0
# 26              76.0
# 27              76.0
# 28              76.0
# 29              76.0
# ..               ...
# 119             76.0
# 120             76.0
# 121             76.0
# 122             76.0
# 123             76.0
# 124             76.0
# 125             76.0
# 126             76.0
# 127             76.0
# 128             76.0
# 129             76.0
# 130             76.0
# 131             76.0
# 132             76.0
# 133             76.0
# 134             76.0
# 135             76.0
# 136             76.0
# 137             76.0
# 138             76.0
# 139             76.0
# 140             76.0
# 141             76.0
# 142             76.0
# 143             76.0
# 144             76.0
# 145             76.0
# 146             76.0
# 147             76.0
# 148             76.0
#
# [149 rows x 14 columns]

# %%
copy_sra_data(df_paired, sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/paired')
copy_sra_data(df_unpaired, sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/single')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 122.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 227.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 234.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 178.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 233.61it/s]
# 100%|██████████| 2/2 [00:00<00:00, 250.55it/s]
# 100%|██████████| 14/14 [00:00<00:00, 219.38it/s]
# 100%|██████████| 18/18 [00:00<00:00, 249.19it/s]
# 100%|██████████| 13/13 [00:00<00:00, 222.07it/s]
# 100%|██████████| 10/10 [00:00<00:00, 199.25it/s]
# 100%|██████████| 11/11 [00:00<00:00, 213.72it/s]
# 100%|██████████| 10/10 [00:00<00:00, 187.28it/s]
# 100%|██████████| 8/8 [00:00<00:00, 215.97it/s]
# 100%|██████████| 19/19 [00:00<00:00, 218.56it/s]
# 100%|██████████| 20/20 [00:00<00:00, 250.00it/s]
# 100%|██████████| 15/15 [00:00<00:00, 254.78it/s]

# %%
def create_config_file(df, samples_to_process_dir, strategy=None):
    df_grouped = df.groupby(['taxon_id'])

    for taxon_id, df_group in df_grouped:
        assert len(
            df_group['study_accession'].unique()) == 1, 'Multiple SRPs found'
        species = taxon_id_map[taxon_id]
        srp = df_group['study_accession'].unique()[0]
        filepath = os.path.join(re_ribo_config_dir, '{}_{}.py'.format(species, srp))
        if strategy:
            filepath = os.path.join(re_ribo_config_dir, '{}_{}_{}.py'.format(species, srp, strategy))
            
        with open(filepath, 'w') as fh:

            config = write_config(species, srp, samples_to_process_dir)
            fh.write(config)
            print('Wrote {}'.format(filepath))

# %%
def write_config(species, srp, samples_to_process_dir):
    rawdata_dir = os.path.join(samples_to_process_dir, species, srp)
    out_dir = os.path.join(re_ribo_analysis_dir, species, srp)
    cdna_fa = cdna_map[species]    
    cdna_idx = cdna_map[species].replace('.fa.gz', '.kallisto.index')
    to_write = """
    RAWDATA_DIR = '{}'
    OUT_DIR = '{}'
    CDNA_FA_GZ = '{}'    
    CDNA_IDX = '{}'    
    """.format(rawdata_dir, out_dir, cdna_fa, cdna_idx)
    return dedent(to_write)

# %%
1666049 2312368 3462856 4651068 5738989 6743138 7648609 8646572 9174364 0054930

# %%
srp = 'SRP012040'
df = db.sra_convert(srp)
#copy_sra_data(df)
#create_config_file(df)
df_paired = df[df.avg_read_length>76]
df_unpaired = df[df.library_layout.str.contains('SINGLE')]
if len(df_paired.index):
    copy_sra_data(df_paired, sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/paired')
    create_config_file(df_paired,  '/staging/as/skchoudh/rna-seq-datasets/paired', 'paired')
if len(df_unpaired.index):
    copy_sra_data(df_unpaired, sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/single')
    create_config_file(df_unpaired,'/staging/as/skchoudh/rna-seq-datasets/single', 'single')
# Out:
# 100%|██████████| 125/125 [00:00<00:00, 736.37it/s]
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/mus_musculus_SRP012040_paired.py

# %%
df_unpaired
# Out:
# Empty DataFrame
# Columns: [study_accession, experiment_accession, experiment_title, run_accession, taxon_id, library_selection, library_layout, library_strategy, library_source, library_name, bases, spots, adapter_spec, avg_read_length]
# Index: []

# %%
srp = 'SRP012040'
df = db.sra_convert(srp)
#copy_sra_data(df)
#create_config_file(df)
df_paired = df[df.avg_read_length>76]
df_unpaired = df[df.library_layout.str.contains('SINGLE')]
copy_sra_data(df_paired, sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/paired')
copy_sra_data(df_unpaired, sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/single')
create_config_file(df_paired,  '/staging/as/skchoudh/rna-seq-datasets/paired', 'paired')
create_config_file(df_unpaired,'/staging/as/skchoudh/rna-seq-datasets/single', 'single')
# Out:
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/mus_musculus_SRP012040_paired.py

# %%
srp = 'SRP000941'
df = db.sra_convert(srp)
df = df[df.library_strategy == 'RNA-Seq']
df_paired = df[df.library_layout.str.contains('PAIRED')]
df_unpaired = df[df.library_layout.str.contains('SINGLE')]
copy_sra_data(df_paired, sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/paired')
copy_sra_data(df_unpaired, sra_dest_dir='/staging/as/skchoudh/rna-seq-datasets/single')
create_config_file(df_paired,  '/staging/as/skchoudh/rna-seq-datasets/paired', 'paired')
create_config_file(df_unpaired,'/staging/as/skchoudh/rna-seq-datasets/single', 'single')
# Out:
# 100%|██████████| 324/324 [00:00<00:00, 478.22it/s]
# 100%|██████████| 29/29 [00:00<00:00, 559.09it/s]
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/homo_sapiens_SRP000941_paired.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/homo_sapiens_SRP000941_single.py

# %%
df_paired
# Out:
#      study_accession experiment_accession  \
# 1886       SRP000941            SRX263860
# 1887       SRP000941            SRX263860
# 1888       SRP000941            SRX263860
# 1889       SRP000941            SRX263860
# 1890       SRP000941            SRX263862
# 1891       SRP000941            SRX263862
# 1892       SRP000941            SRX263862
# 1893       SRP000941            SRX263862
# 1894       SRP000941            SRX263864
# 1895       SRP000941            SRX263864
# 1896       SRP000941            SRX263864
# 1897       SRP000941            SRX263864
# 1898       SRP000941            SRX263866
# 1899       SRP000941            SRX263866
# 1900       SRP000941            SRX263866
# 1901       SRP000941            SRX263866
# 1902       SRP000941            SRX263868
# 1903       SRP000941            SRX263868
# 1904       SRP000941            SRX263868
# 1905       SRP000941            SRX263868
# 1906       SRP000941            SRX263872
# 1907       SRP000941            SRX263872
# 1908       SRP000941            SRX263872
# 1909       SRP000941            SRX263872
# 1910       SRP000941            SRX263857
# 1911       SRP000941            SRX263857
# 1912       SRP000941            SRX263857
# 1913       SRP000941            SRX263857
# 1914       SRP000941            SRX263859
# 1915       SRP000941            SRX263859
# ...              ...                  ...
# 2219       SRP000941            SRX190128
# 2220       SRP000941            SRX190128
# 2221       SRP000941            SRX190130
# 2222       SRP000941            SRX190110
# 2223       SRP000941            SRX190110
# 2224       SRP000941            SRX190110
# 2225       SRP000941            SRX190138
# 2226       SRP000941            SRX190138
# 2227       SRP000941            SRX190138
# 2228       SRP000941            SRX190138
# 2229       SRP000941            SRX190140
# 2230       SRP000941            SRX190140
# 2231       SRP000941            SRX190140
# 2232       SRP000941            SRX190140
# 2233       SRP000941            SRX190140
# 2234       SRP000941            SRX190140
# 2235       SRP000941            SRX190142
# 2236       SRP000941            SRX190142
# 2237       SRP000941            SRX190142
# 2238       SRP000941            SRX190142
# 2252       SRP000941            SRX142107
# 2253       SRP000941            SRX142108
# 2254       SRP000941            SRX142109
# 2255       SRP000941            SRX142110
# 2256       SRP000941            SRX142113
# 2257       SRP000941            SRX142114
# 2258       SRP000941            SRX142111
# 2259       SRP000941            SRX142112
# 2260       SRP000941            SRX142115
# 2261       SRP000941            SRX142116
#
#                                        experiment_title run_accession  \
# 1886           polyA RNA sequencing of STL001 Fat Cells    SRR1045522
# 1887           polyA RNA sequencing of STL001 Fat Cells    SRR1045523
# 1888           polyA RNA sequencing of STL001 Fat Cells    SRR1045524
# 1889           polyA RNA sequencing of STL001 Fat Cells    SRR1045525
# 1890       polyA RNA sequencing of STL001 Gastric Cells    SRR1045526
# 1891       polyA RNA sequencing of STL001 Gastric Cells    SRR1045527
# 1892       polyA RNA sequencing of STL001 Gastric Cells    SRR1045528
# 1893       polyA RNA sequencing of STL001 Gastric Cells    SRR1045529
# 1894          polyA RNA sequencing of STL001 Lung Cells    SRR1045530
# 1895          polyA RNA sequencing of STL001 Lung Cells    SRR1045531
# 1896          polyA RNA sequencing of STL001 Lung Cells    SRR1045532
# 1897          polyA RNA sequencing of STL001 Lung Cells    SRR1045533
# 1898         polyA RNA sequencing of STL001 Psoas Cells    SRR1045570
# 1899         polyA RNA sequencing of STL001 Psoas Cells    SRR1045571
# 1900         polyA RNA sequencing of STL001 Psoas Cells    SRR1045572
# 1901         polyA RNA sequencing of STL001 Psoas Cells    SRR1045573
# 1902  polyA RNA sequencing of STL001 Right Ventricle...    SRR1045574
# 1903  polyA RNA sequencing of STL001 Right Ventricle...    SRR1045575
# 1904  polyA RNA sequencing of STL001 Right Ventricle...    SRR1045576
# 1905  polyA RNA sequencing of STL001 Right Ventricle...    SRR1045577
# 1906        polyA RNA sequencing of STL001 Spleen Cells    SRR1045578
# 1907        polyA RNA sequencing of STL001 Spleen Cells    SRR1045579
# 1908        polyA RNA sequencing of STL001 Spleen Cells    SRR1045580
# 1909        polyA RNA sequencing of STL001 Spleen Cells    SRR1045581
# 1910       polyA RNA sequencing of STL002 Adrenal Cells    SRR1045582
# 1911       polyA RNA sequencing of STL002 Adrenal Cells    SRR1045583
# 1912       polyA RNA sequencing of STL002 Adrenal Cells    SRR1045584
# 1913       polyA RNA sequencing of STL002 Adrenal Cells    SRR1045585
# 1914     polyA RNA sequencing of STL002 Esophagus Cells    SRR1045586
# 1915     polyA RNA sequencing of STL002 Esophagus Cells    SRR1045587
# ...                                                 ...           ...
# 2219  polyA RNA sequencing of STL003 Esophagus Cultu...     SRR651688
# 2220  polyA RNA sequencing of STL003 Esophagus Cultu...     SRR651689
# 2221  polyA RNA sequencing of STL003 Fat Cultured Cells     SRR651691
# 2222  polyA RNA sequencing of STL001 Left Ventricle ...     SRR651692
# 2223  polyA RNA sequencing of STL001 Left Ventricle ...     SRR651693
# 2224  polyA RNA sequencing of STL001 Left Ventricle ...     SRR651694
# 2225  polyA RNA sequencing of STL003 Pancreas Cultur...     SRR651695
# 2226  polyA RNA sequencing of STL003 Pancreas Cultur...     SRR651696
# 2227  polyA RNA sequencing of STL003 Pancreas Cultur...     SRR651697
# 2228  polyA RNA sequencing of STL003 Pancreas Cultur...     SRR651698
# 2229  polyA RNA sequencing of STL003 Psoas Cultured ...     SRR651699
# 2230  polyA RNA sequencing of STL003 Psoas Cultured ...     SRR651700
# 2231  polyA RNA sequencing of STL003 Psoas Cultured ...     SRR651701
# 2232  polyA RNA sequencing of STL003 Psoas Cultured ...     SRR651702
# 2233  polyA RNA sequencing of STL003 Psoas Cultured ...     SRR651703
# 2234  polyA RNA sequencing of STL003 Psoas Cultured ...     SRR651704
# 2235  polyA RNA sequencing of STL003 Right Atrium Cu...     SRR651705
# 2236  polyA RNA sequencing of STL003 Right Atrium Cu...     SRR651706
# 2237  polyA RNA sequencing of STL003 Right Atrium Cu...     SRR651707
# 2238  polyA RNA sequencing of STL003 Right Atrium Cu...     SRR651708
# 2252  polyA RNA sequencing of H1 BMP4 Derived Tropho...     SRR486237
# 2253  polyA RNA sequencing of H1 BMP4 Derived Tropho...     SRR486238
# 2254  polyA RNA sequencing of H1 derived mesenchymal...     SRR486239
# 2255  polyA RNA sequencing of H1 derived mesenchymal...     SRR486240
# 2256  polyA RNA sequencing of H1 Derived Neuronal Pr...     SRR486241
# 2257  polyA RNA sequencing of H1 Derived Neuronal Pr...     SRR486242
# 2258  polyA RNA sequencing of H1 BMP4 Derived Mesend...     SRR488136
# 2259  polyA RNA sequencing of H1 BMP4 Derived Mesend...     SRR488137
# 2260                   polyA RNA sequencing of H1 cells     SRR488684
# 2261                   polyA RNA sequencing of H1 cells     SRR488685
#
#       taxon_id library_selection library_layout library_strategy  \
# 1886      9606              cDNA      PAIRED -           RNA-Seq
# 1887      9606              cDNA      PAIRED -           RNA-Seq
# 1888      9606              cDNA      PAIRED -           RNA-Seq
# 1889      9606              cDNA      PAIRED -           RNA-Seq
# 1890      9606              cDNA      PAIRED -           RNA-Seq
# 1891      9606              cDNA      PAIRED -           RNA-Seq
# 1892      9606              cDNA      PAIRED -           RNA-Seq
# 1893      9606              cDNA      PAIRED -           RNA-Seq
# 1894      9606              cDNA      PAIRED -           RNA-Seq
# 1895      9606              cDNA      PAIRED -           RNA-Seq
# 1896      9606              cDNA      PAIRED -           RNA-Seq
# 1897      9606              cDNA      PAIRED -           RNA-Seq
# 1898      9606              cDNA      PAIRED -           RNA-Seq
# 1899      9606              cDNA      PAIRED -           RNA-Seq
# 1900      9606              cDNA      PAIRED -           RNA-Seq
# 1901      9606              cDNA      PAIRED -           RNA-Seq
# 1902      9606              cDNA      PAIRED -           RNA-Seq
# 1903      9606              cDNA      PAIRED -           RNA-Seq
# 1904      9606              cDNA      PAIRED -           RNA-Seq
# 1905      9606              cDNA      PAIRED -           RNA-Seq
# 1906      9606              cDNA      PAIRED -           RNA-Seq
# 1907      9606              cDNA      PAIRED -           RNA-Seq
# 1908      9606              cDNA      PAIRED -           RNA-Seq
# 1909      9606              cDNA      PAIRED -           RNA-Seq
# 1910      9606              cDNA      PAIRED -           RNA-Seq
# 1911      9606              cDNA      PAIRED -           RNA-Seq
# 1912      9606              cDNA      PAIRED -           RNA-Seq
# 1913      9606              cDNA      PAIRED -           RNA-Seq
# 1914      9606              cDNA      PAIRED -           RNA-Seq
# 1915      9606              cDNA      PAIRED -           RNA-Seq
# ...        ...               ...            ...              ...
# 2219      9606              cDNA      PAIRED -           RNA-Seq
# 2220      9606              cDNA      PAIRED -           RNA-Seq
# 2221      9606              cDNA      PAIRED -           RNA-Seq
# 2222      9606              cDNA      PAIRED -           RNA-Seq
# 2223      9606              cDNA      PAIRED -           RNA-Seq
# 2224      9606              cDNA      PAIRED -           RNA-Seq
# 2225      9606              cDNA      PAIRED -           RNA-Seq
# 2226      9606              cDNA      PAIRED -           RNA-Seq
# 2227      9606              cDNA      PAIRED -           RNA-Seq
# 2228      9606              cDNA      PAIRED -           RNA-Seq
# 2229      9606              cDNA      PAIRED -           RNA-Seq
# 2230      9606              cDNA      PAIRED -           RNA-Seq
# 2231      9606              cDNA      PAIRED -           RNA-Seq
# 2232      9606              cDNA      PAIRED -           RNA-Seq
# 2233      9606              cDNA      PAIRED -           RNA-Seq
# 2234      9606              cDNA      PAIRED -           RNA-Seq
# 2235      9606              cDNA      PAIRED -           RNA-Seq
# 2236      9606              cDNA      PAIRED -           RNA-Seq
# 2237      9606              cDNA      PAIRED -           RNA-Seq
# 2238      9606              cDNA      PAIRED -           RNA-Seq
# 2252      9606              cDNA      PAIRED -           RNA-Seq
# 2253      9606              cDNA      PAIRED -           RNA-Seq
# 2254      9606              cDNA      PAIRED -           RNA-Seq
# 2255      9606              cDNA      PAIRED -           RNA-Seq
# 2256      9606              cDNA      PAIRED -           RNA-Seq
# 2257      9606              cDNA      PAIRED -           RNA-Seq
# 2258      9606              cDNA      PAIRED -           RNA-Seq
# 2259      9606              cDNA      PAIRED -           RNA-Seq
# 2260      9606              cDNA      PAIRED -           RNA-Seq
# 2261      9606              cDNA      PAIRED -           RNA-Seq
#
#       library_source                      library_name        bases  \
# 1886  TRANSCRIPTOMIC        polyA-RNA-seq_STL001FT_r1a   1106627800
# 1887  TRANSCRIPTOMIC        polyA-RNA-seq_STL001FT_r1a   1897588600
# 1888  TRANSCRIPTOMIC        polyA-RNA-seq_STL001FT_r1a   1901851200
# 1889  TRANSCRIPTOMIC        polyA-RNA-seq_STL001FT_r1a   1891729200
# 1890  TRANSCRIPTOMIC        polyA-RNA-seq_STL001GA_r1a   1189486000
# 1891  TRANSCRIPTOMIC        polyA-RNA-seq_STL001GA_r1a   2058524000
# 1892  TRANSCRIPTOMIC        polyA-RNA-seq_STL001GA_r1a   2074740800
# 1893  TRANSCRIPTOMIC        polyA-RNA-seq_STL001GA_r1a   2065242800
# 1894  TRANSCRIPTOMIC        polyA-RNA-seq_STL001LG_r1a   2142985400
# 1895  TRANSCRIPTOMIC        polyA-RNA-seq_STL001LG_r1a   3656058800
# 1896  TRANSCRIPTOMIC        polyA-RNA-seq_STL001LG_r1a   3667540200
# 1897  TRANSCRIPTOMIC        polyA-RNA-seq_STL001LG_r1a   3642243000
# 1898  TRANSCRIPTOMIC        polyA-RNA-seq_STL001PO_r1a   1413726600
# 1899  TRANSCRIPTOMIC        polyA-RNA-seq_STL001PO_r1a   2419977800
# 1900  TRANSCRIPTOMIC        polyA-RNA-seq_STL001PO_r1a   2438054800
# 1901  TRANSCRIPTOMIC        polyA-RNA-seq_STL001PO_r1a   2421843000
# 1902  TRANSCRIPTOMIC        polyA-RNA-seq_STL001RV_r1a   2495629600
# 1903  TRANSCRIPTOMIC        polyA-RNA-seq_STL001RV_r1a   4297002000
# 1904  TRANSCRIPTOMIC        polyA-RNA-seq_STL001RV_r1a   4329575000
# 1905  TRANSCRIPTOMIC        polyA-RNA-seq_STL001RV_r1a   4307549600
# 1906  TRANSCRIPTOMIC        polyA-RNA-seq_STL001SX_r1a   1295366200
# 1907  TRANSCRIPTOMIC        polyA-RNA-seq_STL001SX_r1a   2223383800
# 1908  TRANSCRIPTOMIC        polyA-RNA-seq_STL001SX_r1a   2240800600
# 1909  TRANSCRIPTOMIC        polyA-RNA-seq_STL001SX_r1a   2230500400
# 1910  TRANSCRIPTOMIC        polyA-RNA-seq_STL002AD_r1a   2197840400
# 1911  TRANSCRIPTOMIC        polyA-RNA-seq_STL002AD_r1a   3787001800
# 1912  TRANSCRIPTOMIC        polyA-RNA-seq_STL002AD_r1a   3824025400
# 1913  TRANSCRIPTOMIC        polyA-RNA-seq_STL002AD_r1a   3805166600
# 1914  TRANSCRIPTOMIC        polyA-RNA-seq_STL002EG_r1a   2152801600
# 1915  TRANSCRIPTOMIC        polyA-RNA-seq_STL002EG_r1a   3686262000
# ...              ...                               ...          ...
# 2219  TRANSCRIPTOMIC        polyA-RNA-seq_STL003EG_r1a   5281263400
# 2220  TRANSCRIPTOMIC        polyA-RNA-seq_STL003EG_r1a   1842034000
# 2221  TRANSCRIPTOMIC        polyA-RNA-seq_STL003FT_r1a   5106506000
# 2222  TRANSCRIPTOMIC        polyA-RNA-seq_STL001LV_r1a   6131166800
# 2223  TRANSCRIPTOMIC        polyA-RNA-seq_STL001LV_r1a    623313000
# 2224  TRANSCRIPTOMIC        polyA-RNA-seq_STL001LV_r1a   3090859000
# 2225  TRANSCRIPTOMIC        polyA-RNA-seq_STL003PA_r1a   5538316800
# 2226  TRANSCRIPTOMIC        polyA-RNA-seq_STL003PA_r1a   5252861200
# 2227  TRANSCRIPTOMIC        polyA-RNA-seq_STL003PA_r1a   1065484000
# 2228  TRANSCRIPTOMIC        polyA-RNA-seq_STL003PA_r1a   2886417200
# 2229  TRANSCRIPTOMIC        polyA-RNA-seq_STL003PO_r1a   6893292800
# 2230  TRANSCRIPTOMIC        polyA-RNA-seq_STL003PO_r1a  13230874000
# 2231  TRANSCRIPTOMIC        polyA-RNA-seq_STL003PO_r1a  13312131200
# 2232  TRANSCRIPTOMIC        polyA-RNA-seq_STL003PO_r1a  13273159400
# 2233  TRANSCRIPTOMIC        polyA-RNA-seq_STL003
# 674        SRP000941            SRX007165
# 675        SRP000941            SRX007167
# 711        SRP000941            SRX056684
# 712        SRP000941            SRX056685
# 713        SRP000941            SRX056686
# 714        SRP000941            SRX056680
# 715        SRP000941            SRX056681
# 716        SRP000941            SRX056682
# 717        SRP000941            SRX056683
# 718        SRP000941            SRX056678
# 1340       SRP000941            SRX007165
# 1341       SRP000941            SRX007165
# 1342       SRP000941            SRX007165
# 1343       SRP000941            SRX007165
# 1344       SRP000941            SRX007167
# 1345       SRP000941            SRX007167
# 1346       SRP000941            SRX007167
# 1519       SRP000941            SRX398166
# 1520       SRP000941            SRX398167
# 1521       SRP000941            SRX398172
# 1522       SRP000941            SRX398173
# 1523       SRP000941            SRX398164
# 1524       SRP000941            SRX398165
# 1525       SRP000941            SRX398168
# 1526       SRP000941            SRX398169
# 1527       SRP000941            SRX398170
# 1528       SRP000941            SRX398171
#
#                                        experiment_title run_accession  \
# 672       Sequencing of small RNA from the H1 cell line     SRR020285
# 673    Sequencing of small RNA from the IMR90 cell line     SRR020286
# 674   Strand-specific, shotgun sequencing of mRNA fr...     SRR020287
# 675   Strand-specific, shotgun sequencing of mRNA fr...     SRR020292
# 711   Shotgun sequencing of polyA+ RNA isolated from...     SRR179588
# 712   Shotgun sequencing of polyA+ RNA isolated from...     SRR179589
# 713   Shotgun sequencing of polyA+ RNA isolated from...     SRR179590
# 714   Shotgun sequencing of polyA+ RNA isolated from...     SRR179591
# 715   Shotgun sequencing of polyA+ RNA isolated from...     SRR179592
# 716   Shotgun sequencing of polyA+ RNA isolated from...     SRR179593
# 717   Shotgun sequencing of polyA+ RNA isolated from...     SRR179594
# 718   Shotgun sequencing of polyA+ RNA isolated from...     SRR304995
# 1340  Strand-specific, shotgun sequencing of mRNA fr...     SRR020288
# 1341  Strand-specific, shotgun sequencing of mRNA fr...     SRR020289
# 1342  Strand-specific, shotgun sequencing of mRNA fr...     SRR020290
# 1343  Strand-specific, shotgun sequencing of mRNA fr...     SRR020291
# 1344  Strand-specific, shotgun sequencing of mRNA fr...     SRR020293
# 1345  Strand-specific, shotgun sequencing of mRNA fr...     SRR020294
# 1346  Strand-specific, shotgun sequencing of mRNA fr...     SRR020295
# 1519                    smRNA sequencing of of H1 cells    SRR1057683
# 1520                    smRNA sequencing of of H1 cells    SRR1057684
# 1521  smRNA sequencing of of H1 derived Mesendoderm ...    SRR1057685
# 1522  smRNA sequencing of of H1 derived Mesendoderm ...    SRR1057686
# 1523  smRNA sequencing of of H1 derived mesenchymal ...    SRR1057687
# 1524  smRNA sequencing of of H1 derived mesenchymal ...    SRR1057688
# 1525  smRNA sequencing of of H1 derived Neuronal Pro...    SRR1057689
# 1526  smRNA sequencing of of H1 derived Neuronal Pro...    SRR1057690
# 1527  smRNA sequencing of of H1 BMP4 derived Trophob...    SRR1057691
# 1528  smRNA sequencing of of H1 BMP4 derived Trophob...    SRR1057692
#
#       taxon_id library_selection library_layout library_strategy  \
# 672       9606              cDNA      SINGLE -           RNA-Seq
# 673       9606              cDNA      SINGLE -           RNA-Seq
# 674       9606              cDNA      SINGLE -           RNA-Seq
# 1519  TRANSCRIPTOMIC              smRNA-seq_h1_r1a  2055496100  20554961
# 1520  TRANSCRIPTOMIC              smRNA-seq_h1_r2a  1839321200  18393212
# 1521  TRANSCRIPTOMIC  smRNA-seq_h1-mesendoderm_r1a  1892226400  18922264
# 1522  TRANSCRIPTOMIC  smRNA-seq_h1-mesendoderm_r2a  1902241300  19022413
# 1523  TRANSCRIPTOMIC          smRNA-seq_h1-msc_r1a  2100901900  21009019
# 1524  TRANSCRIPTOMIC          smRNA-seq_h1-msc_r2a  2269597100  22695971
# 1525  TRANSCRIPTOMIC          smRNA-seq_h1-npc_r1a  1905100100  19051001
# 1526  TRANSCRIPTOMIC          smRNA-seq_h1-npc_r2a  1965604800  19656048
# 1527  TRANSCRIPTOMIC         smRNA-seq_h1-bmp4_r1a  1868239000  18682390
# 1528  TRANSCRIPTOMIC         smRNA-seq_h1-bmp4_r2a  1981367300  19813673
#
#      adapter_spec  avg_read_length
# 672          None             43.0
# 673          None             43.0
# 674          None             43.0
# 675          None             43.0
# 711          None             50.0
# 712          None             50.0
# 713          None             50.0
# 714          None             50.0
# 715          None             50.0
# 716          None             50.0
# 717          None             50.0
# 718          None             50.0
# 1340         None             87.0
# 1341         None             87.0
# 1342         None             87.0
# 1343         None             87.0
# 1344         None             87.0
# 1345         None             87.0
# 1346         None             87.0
# 1519         None            100.0
# 1520         None            100.0
# 1521         None            100.0
# 1522         None            100.0
# 1523         None            100.0
# 1524         None            100.0
# 1525         None            100.0
# 1526         None            100.0
# 1527         None            100.0
# 1528         None            100.0

# %%
for index, row in df_paired.iterrows():
    if not os.path.exists('/staging/as/skchoudh/SRA_datasets/SRP000941/{}/{}.sra'.format(row['experiment_accession'], row['run_accession'])):
        print('{}/{}.sra'.format(row['experiment_accession'], row['run_accession']))

# %%
for index, row in df_unpaired.iterrows():
    if not os.path.exists('/staging/as/skchoudh/SRA_datasets/SRP000941/{}/{}.sra'.format(row['experiment_accession'], row['run_accession'])):
        print('{}'.format(row['experiment_accession']))

# %%
create_config_file(df_paired,  '/staging/as/skchoudh/rna-seq-datasets/paired', 'paired')
# Out:
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/homo_sapiens_SRP000941_paired.py

# %%
create_config_file(df_unpaired,'/staging/as/skchoudh/rna-seq-datasets/single', 'single')
# Out:
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/homo_sapiens_SRP000941_single.py

# %%
create_config_file(df_paired,  '/staging/as/skchoudh/rna-seq-datasets/paired', 'paired')
# Out:
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/macaca_mulatta_SRP007412_paired.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/gorilla_gorilla_SRP007412_paired.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/pan_paniscus_SRP007412_paired.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/pan_troglodytes_SRP007412_paired.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/pongo_abelii_SRP007412_paired.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/homo_sapiens_SRP007412_paired.py

# %%
create_config_file(df_unpaired,'/staging/as/skchoudh/rna-seq-datasets/single', 'single')
# Out:
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/gallus_gallus_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/ornithorhynchus_anatinus_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/macaca_mulatta_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/gorilla_gorilla_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/pan_paniscus_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/pan_troglodytes_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/pongo_abelii_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/homo_sapiens_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/mus_musculus_SRP007412_single.py
# Wrote /home/cmb-panasas2/skchoudh/github_projects/EE-546-project//snakemake/configs/monodelphis_domestica_SRP007412_single.py
